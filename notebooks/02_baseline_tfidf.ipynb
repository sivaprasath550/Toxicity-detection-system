# %% [markdown]
# # Stage 0 baseline: TF-IDF + LogisticRegression
#
# Thin wrapper around `src/baseline.py` -- see that file for the actual implementation. This notebook is for inspecting intermediate output (top TF-IDF features per class, score distribution) that a script run does not surface.

# %% [markdown]
# ## Run baseline.py

# %% [markdown]
# ## Inspect top features

# %% [markdown]
# ## Score distribution + bias table
